# %% [markdown]
# # 🤖 Wall-Following Robot Sensor Data Analysis
#
# This project focuses on exploring and analyzing sensor data collected from a wall-following robot using Python and Pandas.
#
# The goal is to build practical Pandas skills while working with a real robotics-related dataset.

# %% [markdown]
# ## 1. Import Pandas and Load the Dataset
#
# First, we import the Pandas library and load the robot sensor dataset into a DataFrame.

# %%
import numpy as np 
import pandas as pd

# %%
pd.read_csv(r'sensor_readings_24.csv')
# Out:
#       0.438  0.498  3.625  3.645  5.000  2.918  5.000.1  2.351  2.332  2.643  \
# 0     0.438  0.498  3.625  3.648  5.000  2.918    5.000  2.637  2.332  2.649
# 1     0.438  0.498  3.625  3.629  5.000  2.918    5.000  2.637  2.334  2.643
# 2     0.437  0.501  3.625  3.626  5.000  2.918    5.000  2.353  2.334  2.642
# 3     0.438  0.498  3.626  3.629  5.000  2.918    5.000  2.640  2.334  2.639
# 4     0.439  0.498  3.626  3.629  5.000  2.918    5.000  2.633  2.334  2.645
# ...     ...    ...    ...    ...    ...    ...      ...    ...    ...    ...
# 5450  0.910  5.000  3.997  2.785  2.770  2.572    2.433  1.087  1.772  1.040
# 5451  0.926  5.000  4.015  2.792  2.777  2.571    1.768  1.071  1.762  1.021
# 5452  0.937  5.000  4.034  2.799  2.784  2.571    1.754  1.053  1.752  1.002
# 5453  0.945  4.052  4.052  2.809  2.791  2.441    1.757  1.034  1.743  0.983
# 5454  0.950  4.066  5.000  2.819  2.798  2.570    2.422  1.016  1.739  0.964
#
# ...

# %%
df = pd.read_csv(r'sensor_readings_24.csv')

# %%
column_names = [f"US{i}" for i in range(1, 25)] + ["Class"]

df = pd.read_csv(
    "sensor_readings_24.csv",
    header=None,
    names=column_names
)

# %% [markdown]
# ## 2. Dataset Dimensions
#
# In this step, we checked the number of rows and columns present in the dataset.

# %%
# Find the number of rows and columns in the dataset
df.shape
# Out:
# (5456, 25)

# %% [markdown]
# The dataset currently contains 5,455 rows and 25 columns.

# %% [markdown]
# ## 3. Column Names
#
# In this step, we inspected all column names available in the DataFrame.

# %%
# Find all column names in the dataset
df.columns
# Out:
# Index(['US1', 'US2', 'US3', 'US4', 'US5', 'US6', 'US7', 'US8', 'US9', 'US10',
#        'US11', 'US12', 'US13', 'US14', 'US15', 'US16', 'US17', 'US18', 'US19',
#        'US20', 'US21', 'US22', 'US23', 'US24', 'Class'],
#       dtype='object')

# %% [markdown]
# ## 4. Inspect the First Five Rows
#
# In this step, we inspected the first five rows to understand how the dataset has been loaded and how the values are structured.

# %%
# Inspect the first five rows of the dataset
df.head()
# Out:
#      US1    US2    US3    US4  US5    US6  US7    US8    US9   US10  ...  \
# 0  0.438  0.498  3.625  3.645  5.0  2.918  5.0  2.351  2.332  2.643  ...
# 1  0.438  0.498  3.625  3.648  5.0  2.918  5.0  2.637  2.332  2.649  ...
# 2  0.438  0.498  3.625  3.629  5.0  2.918  5.0  2.637  2.334  2.643  ...
# 3  0.437  0.501  3.625  3.626  5.0  2.918  5.0  2.353  2.334  2.642  ...
# 4  0.438  0.498  3.626  3.629  5.0  2.918  5.0  2.640  2.334  2.639  ...
#
#     US16   US17   US18   US19   US20   US21   US22   US23   US24  \
# 0  0.593  0.502  0.493  0.504  0.445  0.431  0.444  0.440  0.429
# 1  0.592  0.502  0.493  0.504  0.449  0.431  0.444  0.443  0.429
# 2  0.593  0.502  0.493  0.504  0.449  0.431  0.444  0.446  0.429
# 3  0.593  0.502  0.493  0.504  0.449  0.431  0.444  0.444  0.429
# 4  0.592  0.502  0.493  0.504  0.449  0.431  0.444  0.441  0.429
#
#                Class
# 0  Slight-Right-Turn
# 1  Slight-Right-Turn
# 2  Slight-Right-Turn
# 3  Slight-Right-Turn
# 4  Slight-Right-Turn
# ...

# %% [markdown]
# ## 5. Missing Values
#
# In this step, we checked whether the dataset contains missing values.

# %%
# Check for missing values in the dataset
df.isna().sum()
# Out:
# US1      0
# US2      0
# US3      0
# US4      0
# US5      0
# US6      0
# US7      0
# US8      0
# US9      0
# US10     0
# US11     0
# US12     0
# US13     0
# US14     0
# US15     0
# US16     0
# US17     0
# US18     0
# US19     0
# US20     0
# US21     0
# US22     0
# US23     0
# US24     0
# Class    0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
print(f"Total missing values: {df.isna().sum().sum()}")
# Out:
# Total missing values: 0

# %%
df.isna()
# Out:
#         US1    US2    US3    US4    US5    US6    US7    US8    US9   US10  \
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 5451  False  False  False  False  False  False  False  False  False  False
# 5452  False  False  False  False  False  False  False  False  False  False
# 5453  False  False  False  False  False  False  False  False  False  False
# 5454  False  False  False  False  False  False  False  False  False  False
# 5455  False  False  False  False  False  False  False  False  False  False
#
# ...

# %% [markdown]
# The inspection showed `False` values across the displayed dataset, indicating that no missing values were detected in the checked entries.

# %% [markdown]
# ## 6. Data Types

# %%
# Check the data types of all columns
df.dtypes
# Out:
# US1      float64
# US2      float64
# US3      float64
# US4      float64
# US5      float64
# US6      float64
# US7      float64
# US8      float64
# US9      float64
# US10     float64
# US11     float64
# US12     float64
# US13     float64
# US14     float64
# US15     float64
# US16     float64
# US17     float64
# US18     float64
# US19     float64
# US20     float64
# US21     float64
# US22     float64
# US23     float64
# US24     float64
# Class     object
# dtype: object

# %% [markdown]
# ## 7. DataFrame Summary

# %%
# Get a concise summary of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5456 entries, 0 to 5455
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   US1     5456 non-null   float64
#  1   US2     5456 non-null   float64
#  2   US3     5456 non-null   float64
#  3   US4     5456 non-null   float64
#  4   US5     5456 non-null   float64
#  5   US6     5456 non-null   float64
#  6   US7     5456 non-null   float64
#  7   US8     5456 non-null   float64
#  8   US9     5456 non-null   float64
#  9   US10    5456 non-null   float64
#  10  US11    5456 non-null   float64
#  11  US12    5456 non-null   float64
#  12  US13    5456 non-null   float64
#  13  US14    5456 non-null   float64
#  14  US15    5456 non-null   float64
#  15  US16    5456 non-null   float64
#  16  US17    5456 non-null   float64
#  17  US18    5456 non-null   float64
#  18  US19    5456 non-null   float64
#  19  US20    5456 non-null   float64
# ...

# %% [markdown]
# ## 8. Descriptive Statistics

# %%
# Generate descriptive statistics for numerical columns
df.describe()
# Out:
#                US1          US2          US3          US4          US5  \
# count  5456.000000  5456.000000  5456.000000  5456.000000  5456.000000
# mean      1.471617     2.327043     2.489347     2.796501     2.958552
# std       0.802801     1.410146     1.247435     1.309368     1.339225
# min       0.400000     0.437000     0.470000     0.833000     1.120000
# 25%       0.921000     1.362000     1.538750     1.731000     1.774000
# 50%       1.335000     1.904500     2.064000     2.458000     2.667000
# 75%       1.814000     2.681500     2.739250     4.093500     4.314500
# max       5.000000     5.025000     5.029000     5.017000     5.000000
#
#                US6          US7          US8          US9         US10  ...  \
# count  5456.000000  5456.000000  5456.000000  5456.000000  5456.000000  ...
# mean      2.893073     3.351113     2.540397     3.125621     2.832386  ...
# std       1.282575     1.413692     1.111554     1.356965     1.307843  ...
# ...

# %% [markdown]
# ## 9. Assign Proper Column Names

# %%
# Create meaningful column names
new_columnNames = [f"US{i}" for i in range(1, 25)] + ["Class"]

df.columns = new_columnNames

# %%
df.columns
# Out:
# Index(['US1', 'US2', 'US3', 'US4', 'US5', 'US6', 'US7', 'US8', 'US9', 'US10',
#        'US11', 'US12', 'US13', 'US14', 'US15', 'US16', 'US17', 'US18', 'US19',
#        'US20', 'US21', 'US22', 'US23', 'US24', 'Class'],
#       dtype='object')

# %%
df
# Out:
#         US1    US2    US3    US4    US5    US6    US7    US8    US9   US10  \
# 0     0.438  0.498  3.625  3.645  5.000  2.918  5.000  2.351  2.332  2.643
# 1     0.438  0.498  3.625  3.648  5.000  2.918  5.000  2.637  2.332  2.649
# 2     0.438  0.498  3.625  3.629  5.000  2.918  5.000  2.637  2.334  2.643
# 3     0.437  0.501  3.625  3.626  5.000  2.918  5.000  2.353  2.334  2.642
# 4     0.438  0.498  3.626  3.629  5.000  2.918  5.000  2.640  2.334  2.639
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 5451  0.910  5.000  3.997  2.785  2.770  2.572  2.433  1.087  1.772  1.040
# 5452  0.926  5.000  4.015  2.792  2.777  2.571  1.768  1.071  1.762  1.021
# 5453  0.937  5.000  4.034  2.799  2.784  2.571  1.754  1.053  1.752  1.002
# 5454  0.945  4.052  4.052  2.809  2.791  2.441  1.757  1.034  1.743  0.983
# 5455  0.950  4.066  5.000  2.819  2.798  2.570  2.422  1.016  1.739  0.964
#
# ...

# %% [markdown]
# ## 10. Unique Movement Classes

# %%
# Find the unique movement classes
df['Class'].unique()
# Out:
# array(['Slight-Right-Turn', 'Sharp-Right-Turn', 'Move-Forward',
#        'Slight-Left-Turn'], dtype=object)

# %% [markdown]
# ## 11. Movement Class Distribution

# %%
# Count the records in each movement class
df['Class'].value_counts()
# Out:
# Class
# Move-Forward         2205
# Sharp-Right-Turn     2097
# Slight-Right-Turn     826
# Slight-Left-Turn      328
# Name: count, dtype: int64

# %% [markdown]
# ## 12. Movement Class Percentage Distribution

# %%
# Calculate the percentage distribution of each movement class
df['Class'].value_counts()/len(df['Class'])*100
# Out:
# Class
# Move-Forward         40.414223
# Sharp-Right-Turn     38.434751
# Slight-Right-Turn    15.139296
# Slight-Left-Turn      6.011730
# Name: count, dtype: float64

# %% [markdown]
# ## 13. Sort Movement Class Distribution

# %%
percentage = df['Class'].value_counts()/len(df['Class'])*100

# %%
# Sort movement classes by percentage distribution
percentage.sort_values(ascending= False)
# Out:
# Class
# Move-Forward         40.414223
# Sharp-Right-Turn     38.434751
# Slight-Right-Turn    15.139296
# Slight-Left-Turn      6.011730
# Name: count, dtype: float64

# %% [markdown]
# ## 14. Most Common Movement Class

# %%
# Find the most common movement class
df['Class'].value_counts().idxmax()
# Out:
# 'Move-Forward'

# %% [markdown]
# ## 15. Least Common Movement Class

# %%
# Find the least common movement class
df['Class'].value_counts().idxmin()
# Out:
# 'Slight-Left-Turn'

# %% [markdown]
# ## 16. Least Common Class Count

# %%
# Find the count of the least common movement class
df['Class'].value_counts().min()
# Out:
# np.int64(328)

# %% [markdown]
# ## 17. Filter Data

# %%
# Filter Move-Forward records
move_forward = df[df['Class'] == 'Move-Forward']
move_forward
# Out:
#         US1    US2    US3    US4    US5    US6    US7    US8    US9   US10  \
# 65    0.724  0.756  5.000  5.009  3.839  5.000  2.936  2.928  2.843  2.414
# 66    0.733  0.764  0.811  5.004  3.844  5.000  2.936  2.926  2.836  2.416
# 67    0.741  0.776  0.845  0.833  3.849  5.000  2.931  2.923  2.830  2.412
# 68    0.828  0.781  0.817  0.848  3.854  5.000  2.929  2.918  2.824  2.827
# 69    0.761  0.816  0.834  5.000  3.859  5.000  2.938  2.914  2.816  2.405
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 5448  4.604  5.000  3.944  2.765  2.750  2.688  2.445  1.142  1.129  1.095
# 5449  1.646  3.925  3.958  2.771  2.756  2.337  2.439  1.127  1.785  1.077
# 5450  0.911  3.939  3.976  2.775  2.763  2.573  2.436  1.106  1.781  1.059
# 5451  0.910  5.000  3.997  2.785  2.770  2.572  2.433  1.087  1.772  1.040
# 5454  0.945  4.052  4.052  2.809  2.791  2.441  1.757  1.034  1.743  0.983
#
# ...

# %% [markdown]
# ## 18 Sort Data

# %%
# Sort data by US1 in ascending order
df.sort_values(by='US1')
# Out:
#         US1    US2    US3    US4    US5    US6    US7    US8    US9   US10  \
# 672   0.400  0.479  1.454  1.425  1.421  1.436  1.481  1.483  2.714  2.732
# 674   0.400  0.457  1.454  1.425  1.421  1.433  1.484  1.483  2.715  2.729
# 671   0.401  0.482  1.450  1.425  1.421  1.436  1.481  1.483  2.715  2.732
# 670   0.402  0.453  1.454  1.425  1.421  1.433  1.481  1.482  2.715  2.732
# 675   0.402  0.460  1.454  1.425  1.421  1.436  1.481  1.483  2.715  2.729
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2416  5.000  1.515  2.403  2.404  3.097  3.142  5.000  1.134  5.000  1.084
# 3730  5.000  5.000  5.000  1.356  1.368  4.208  4.798  5.000  5.000  2.406
# 3728  5.000  5.000  1.353  1.353  5.000  4.193  4.789  5.000  2.866  3.392
# 3636  5.000  2.627  2.608  2.243  1.808  1.794  1.676  1.259  1.245  1.254
# 5407  5.000  2.623  2.614  2.595  1.868  1.857  1.357  1.352  1.323  1.333
#
# ...

# %% [markdown]
# ## 19 Grouping & Aggregation

# %%
# Calculate the average sensor values for each movement class
df.groupby('Class').mean(numeric_only=True)
# Out:
#                         US1       US2       US3       US4       US5       US6  \
# Class
# Move-Forward       1.329706  2.269341  2.309382  2.683341  2.749585  2.752687
# Sharp-Right-Turn   1.594739  2.413119  2.583308  2.899262  3.173251  3.032242
# Slight-Left-Turn   2.126774  2.385284  2.284290  2.246930  2.115549  1.939930
# Slight-Right-Turn  1.277715  2.239427  2.812645  3.055930  3.306074  3.293007
#
#                         US7       US8       US9      US10  ...      US15  \
# Class                                                      ...
# Move-Forward       3.563091  2.498399  3.438539  2.905246  ...  3.131303
# Sharp-Right-Turn   3.197056  2.676467  3.022066  2.830513  ...  1.152950
# Slight-Left-Turn   2.002198  1.741244  1.790165  1.747564  ...  2.189409
# Slight-Right-Turn  3.711998  2.624402  3.083493  3.073419  ...  2.414415
#
#                        US16      US17      US18      US19      US20      US21  \
# Class
# ...

# %% [markdown]
# ## 20 Data Quality Checks

# %%
# Check for duplicate rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 21 Feature / Target Separation

# %%
# Separate sensor features and movement target
X = df.drop('Class', axis=1)
y = df['Class']

# %%
X
# Out:
#         US1    US2    US3    US4    US5    US6    US7    US8    US9   US10  \
# 0     0.438  0.498  3.625  3.645  5.000  2.918  5.000  2.351  2.332  2.643
# 1     0.438  0.498  3.625  3.648  5.000  2.918  5.000  2.637  2.332  2.649
# 2     0.438  0.498  3.625  3.629  5.000  2.918  5.000  2.637  2.334  2.643
# 3     0.437  0.501  3.625  3.626  5.000  2.918  5.000  2.353  2.334  2.642
# 4     0.438  0.498  3.626  3.629  5.000  2.918  5.000  2.640  2.334  2.639
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 5451  0.910  5.000  3.997  2.785  2.770  2.572  2.433  1.087  1.772  1.040
# 5452  0.926  5.000  4.015  2.792  2.777  2.571  1.768  1.071  1.762  1.021
# 5453  0.937  5.000  4.034  2.799  2.784  2.571  1.754  1.053  1.752  1.002
# 5454  0.945  4.052  4.052  2.809  2.791  2.441  1.757  1.034  1.743  0.983
# 5455  0.950  4.066  5.000  2.819  2.798  2.570  2.422  1.016  1.739  0.964
#
# ...

# %%
y
# Out:
# 0       Slight-Right-Turn
# 1       Slight-Right-Turn
# 2       Slight-Right-Turn
# 3       Slight-Right-Turn
# 4       Slight-Right-Turn
#               ...
# 5451         Move-Forward
# 5452     Sharp-Right-Turn
# 5453     Sharp-Right-Turn
# 5454         Move-Forward
# 5455     Sharp-Right-Turn
# Name: Class, Length: 5456, dtype: object

# %% [markdown]
# ## 22 Final Dataset Preparation

# %%
# Verify the prepared features and target
print(X.shape)
print(y.shape)
print(X.head())
print(y.head())
# Out:
# (5456, 24)
# (5456,)
#      US1    US2    US3    US4  US5    US6  US7    US8    US9   US10  ...  \
# 0  0.438  0.498  3.625  3.645  5.0  2.918  5.0  2.351  2.332  2.643  ...
# 1  0.438  0.498  3.625  3.648  5.0  2.918  5.0  2.637  2.332  2.649  ...
# 2  0.438  0.498  3.625  3.629  5.0  2.918  5.0  2.637  2.334  2.643  ...
# 3  0.437  0.501  3.625  3.626  5.0  2.918  5.0  2.353  2.334  2.642  ...
# 4  0.438  0.498  3.626  3.629  5.0  2.918  5.0  2.640  2.334  2.639  ...
#
#     US15   US16   US17   US18   US19   US20   US21   US22   US23   US24
# 0  1.744  0.593  0.502  0.493  0.504  0.445  0.431  0.444  0.440  0.429
# 1  1.744  0.592  0.502  0.493  0.504  0.449  0.431  0.444  0.443  0.429
# 2  1.744  0.593  0.502  0.493  0.504  0.449  0.431  0.444  0.446  0.429
# 3  1.744  0.593  0.502  0.493  0.504  0.449  0.431  0.444  0.444  0.429
# 4  1.744  0.592  0.502  0.493  0.504  0.449  0.431  0.444  0.441  0.429
#
# [5 rows x 24 columns]
# 0    Slight-Right-Turn
# 1    Slight-Right-Turn
# ...
